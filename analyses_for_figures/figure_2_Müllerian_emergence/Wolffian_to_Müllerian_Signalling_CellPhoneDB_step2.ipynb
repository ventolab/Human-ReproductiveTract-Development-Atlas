# %% [markdown]
#  ![CellphoneDB Logo](https://www.cellphonedb.org/images/cellphonedb_logo_33.png) CellphoneDB

# %% [markdown]
# ### Check python version

# %%
import pandas as pd
import numpy as np
import sys
import os

pd.set_option('display.max_columns', 100)
# Define our base directory for the analysis
os.chdir('/home/jovyan/RepTract/CELLPHONEDB/')

# %% [markdown]
# Checking that environment contains a Python >= 3.8 as required by CellPhoneDB.

# %%
print(sys.version)
# Out:
# 3.8.16 | packaged by conda-forge | (default, Feb  1 2023, 16:01:55)
# [GCC 11.3.0]

# %% [markdown]
# ___
# ## Input files
# The differential expression method accepts 5 input files (4 mandatory).
# - **cpdb_file_path**: (mandatory) path to the database.
# - **meta_file_path**: (mandatory) path to the meta file linking cell barcodes to cluster labels.
# - **counts_file_path**: (mandatory) paths to normalized counts file (not z-transformed), either in text format or h5ad (recommended).
# - **degs_file_path**: (mandatory) path to the DEG file indicating the differentially expressed genes in each cluster. Only differentially expressed genes that are significant should be included.
# - **microenvs_file_path** (optional) path to microenvironment file that groups cell types/clusters by microenvironments. When providing a microenvironment file, CellphoneDB will restrict the interactions to those cells within the microenvironment.
#
# Both, `degs_file_path` and `microenvs_file_path` content will depend on the biological question that the researcher wants to answer.
#
#
# > In **this example** we are studying how cell-cell interactions change between endometrial cells as epithelia and stromal cells differentiate in response to hormones in the three endoemtrial layers (see image above). Therefore, the `degs_file_path` contains only the genes differentially expressed along the epithelials or stromal/fibroblasts to capture the genes that change along their differentiation in response to progesterone.  The `microenvs_file_path` specifies the cells present in each spaitotemporal compartment of the differentiating endometrium. The `meta_file_path` and `counts_file_path` contain all cells that we are interested in.
#
# > CellphoneDB will retrieve all the interactions occurring between epithelials or stromals and any other celltype in the meta/counts file where: (i) all the proteins are expressed in the corresponding cell type and (ii) at least one gene is differentially expressed by an epithelial/stromal subset.

# %%
cpdb_file_path = '/nfs/team292/vl6/FetalReproductiveTract/v5.0.0/cellphonedb.zip' # this is the downloaded database
meta_file_path = '/nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/meta.tsv'
counts_file_path = '/nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/counts_normalised.h5ad'
microenvs_file_path = '/nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/microenvironments.tsv'
degs_file_path = '/nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/DEGs_upregulated_genes.tsv'
out_path = '/nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/'

# %% [markdown]
# ### Inspect input files

# %% [markdown]
# <span style="color:green">**1)**</span> The **metadata** file is compossed of two columns:
# - **barcode_sample**: this column indicates the barcode of each cell in the experiment.
# - **celltype**: this column denotes the cell label assigned.

# %%
metadata = pd.read_csv(meta_file_path, sep = '\t')
metadata.head(3)
# Out:
#                                 Cell      cell_type
# 0  HD_F_GON13679794_CGGAGCTAGTTAAGTG  Müllerian Epi
# 1  HD_F_GON13679794_GTATCTTCAAGCGCTC  Müllerian Epi
# 2  HD_F_GON13679794_GTCTCGTTCCTGCCAT  Müllerian Epi

# %% [markdown]
# <span style="color:green">**2)**</span>  The **counts** files is a h5ad object from scanpy. The dimensions and order of this object must coincide with the dimensions of the metadata file, i.e. must have the same number of cells in both files.

# %%
import anndata

adata = anndata.read_h5ad(counts_file_path)
adata.shape
# Out:
# (6284, 20582)

# %% [markdown]
# Check barcodes in metadata and counts are the same.

# %%
list(adata.obs.index).sort() == list(metadata['Cell']).sort()
# Out:
# True

# %% [markdown]
# <span style="color:green">**3)**</span> **Differentially expressed genes** file is a two columns file indicating which genes are up-regulated (or specific) in a cell type. The first column corresponds to the cluster name (these match with those in the metadata file) and the second column the up-regulated gene. The remaining columns are ignored by CellPhoneDB. All genes present in this file will be taken into account, thus the user must provide in this file only those genes considered as up-regulated or relevant for the analysis.

# %%
degs = pd.read_csv(degs_file_path, sep = '\t')
degs.head(3)
# Out:
#          cluster    gene  p_val_adj  p_val  avg_log2FC  pct.1  pct.2
# 0  Müllerian Epi  PDLIM1        0.0    0.0    1.292841  0.872  0.103
# 1  Müllerian Epi    CDH2        0.0    0.0    1.202645  0.930  0.133
# 2  Müllerian Epi    PNOC        0.0    0.0    1.139028  0.781  0.084

# %% [markdown]
# <span style="color:green">**4)**</span> **Micronevironments** defines the cell types that belong to a a given microenvironemnt. CellPhoneDB will only calculate interactions between cells that belong to a given microenvironment. In this file we are defining two microenvionments.

# %%
microenv = pd.read_csv(microenvs_file_path, sep = '\t')
microenv
# Out:
#                     celltype microenvironment
# 0              Müllerian Epi            Early
# 1               Wolffian Epi            Early
# 2             Müllerian Mese            Early
# 3  Wolffian/Mesonephros Mese            Early

# %% [markdown]
# Displaying cells grouped per microenvironment

# %%
microenv.groupby('microenvironment')['celltype'].apply(lambda x : list(x.value_counts().index))
# Out:
# microenvironment
# Early    [Müllerian Epi, Wolffian Epi, Müllerian Mese, ...
# Name: celltype, dtype: object

# %% [markdown]
# <span style="color:green">**5)**</span> **Check cell type names are the same**

# %%
# all cells in microenv are in meta
[ item in set(metadata['cell_type']) for item in set(microenv['celltype']) ]
# Out:
# [True, True, True, True]

# %%
# all cells in microenv are in meta - who is not?
list(set(microenv['celltype']) - set(metadata['cell_type']) )
# Out:
# []

# %%
# all cells in degs are in meta
[ item in set(metadata['cell_type']) for item in set(degs['cluster']) ]
# Out:
# [True, True, True, True]

# %%
# all cells in degs are in meta - who is not?
list(set(degs['cluster']) - set(metadata['cell_type']) )
# Out:
# []

# %% [markdown]
# ____
# # Run CellphoneDB with differential analysis (method 3)
# The output of this method will be saved in `out_path` and also assigned to the predefined variables.

# %%
from cellphonedb.src.core.methods import cpdb_degs_analysis_method
res = \
    cpdb_degs_analysis_method.call(
        cpdb_file_path = cpdb_file_path, 
        meta_file_path = meta_file_path, 
        counts_file_path = counts_file_path,
        degs_file_path = degs_file_path,
        counts_data = 'hgnc_symbol',
        microenvs_file_path=microenvs_file_path,
        threshold = 0.1,
        result_precision = 3,
        separator = '|',
        debug = False,
        output_path = out_path,
        output_suffix = None,
        score_interactions = True,
        threads = 4)
# Out:
# [ ][CORE][07/02/25-12:32:02][INFO] [Cluster DEGs Analysis] Threshold:0.1 Precision:3
# Reading user files...
# WARNING: DEGs expects 2 columns and got 7. Dropping extra columns.
# The following user files were loaded successfully:
# /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/counts_normalised.h5ad
# /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/meta.tsv
# /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/microenvironments.tsv
# /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/input/DEGs_upregulated_genes.tsv
# [ ][CORE][07/02/25-12:32:13][INFO] Running Real Analysis
# [ ][CORE][07/02/25-12:32:13][INFO] Limiting cluster combinations using microenvironments
# [ ][CORE][07/02/25-12:32:13][INFO] Running DEGs-based Analysis
# [ ][CORE][07/02/25-12:32:13][INFO] Building results
# [ ][CORE][07/02/25-12:32:14][INFO] Scoring interactions: Filtering genes per cell type..
# 100%|██████████| 4/4 [00:00<00:00, 48.88it/s]
# [ ][CORE][07/02/25-12:32:14][INFO] Scoring interactions: Calculating mean expression of each gene per group/cell type..
# 100%|██████████| 4/4 [00:00<00:00, 175.58it/s]
# [ ][CORE][07/02/25-12:32:14][INFO] Scoring interactions: Calculating scores for all interactions and cell types..
# 100%|██████████| 16/16 [00:02<00:00,  6.57it/s]
# Saved deconvoluted_result to /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/degs_analysis_deconvoluted_result_02_07_2025_123217.txt
# Saved deconvoluted_percents to /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/degs_analysis_deconvoluted_percents_02_07_2025_123217.txt
# Saved means_result to /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/degs_analysis_means_result_02_07_2025_123217.txt
# Saved relevant_interactions_result to /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/degs_analysis_relevant_interactions_result_02_07_2025_123217.txt
# Saved significant_means to /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/degs_analysis_significant_means_02_07_2025_123217.txt
# Saved interaction_scores to /nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/degs_analysis_interaction_scores_02_07_2025_123217.txt

# %%
res.keys()
# Out:
# dict_keys(['deconvoluted_result', 'deconvoluted_percents', 'means_result', 'relevant_interactions_result', 'significant_means', 'interaction_scores'])

# %% [markdown]
# ___
# ### Description of output files

# %% [markdown]
# **Relevant interaction** fields:
# - **id_cp_interaction**: interaction identifier.
# - **interacting_pair**: Name of the interacting pairs.
# - **partner A/B**: Identifier for the first interacting partner (A) or the second (B). It could be: UniProt (prefix simple:) or complex (prefix complex:)
# - **gene A/B**: Gene identifier for the first interacting partner (A) or the second (B).
# - **secreted**: True if one of the partners is secreted.
# - **receptor A/B**: True if the first interacting partner (A) or the second (B) is annotated as a receptor in our database.
# - **annotation_strategy**: Curated if the interaction was annotated by the CellPhoneDB developers. Other value if it was added by the user.
# - **is_integrin**: True if one of the partners is integrin.
# - **cell_a|cell_b**: 1 if interaction is detected as significant, 0 if not.

# %%
res['relevant_interactions_result']
# Out:
#      id_cp_interaction               interacting_pair      partner_a  \
# 0      CPI-SC0A2DB962D     CDH1_integrin_a2b1_complex  simple:P12830
# 2      CPI-SC0C8B7BCBB  COL11A1_integrin_a2b1_complex  simple:P12107
# 4      CPI-SC0B86B7CED  COL12A1_integrin_a2b1_complex  simple:Q99715
# 5      CPI-SC0FA343CEF  COL13A1_integrin_a2b1_complex  simple:Q5TAT6
# 6      CPI-SC0CCCF9A7F  COL14A1_integrin_a2b1_complex  simple:Q05707
# ...                ...                            ...            ...
# 2828   CPI-SS0E7CBFD03                     WNT5A_ROR2  simple:P41221
# 2869   CPI-SS0DBA22B92                      CHL1_CHL1  simple:O00533
# 2870   CPI-SC08497FAC9                  CLCF1_CNTF_1R  simple:Q9UBD9
# 2883   CPI-SS0A612BCEF                      KITLG_KIT  simple:P21583
# 2903   CPI-SS0ABEE4D3D                     RBP4_STRA6  simple:P02753
#
#                           partner_b   gene_a gene_b  secreted  receptor_a  \
# 0     complex:integrin_a2b1_complex     CDH1    NaN     False       False
# 2     complex:integrin_a2b1_complex  COL11A1    NaN      True       False
# 4     complex:integrin_a2b1_complex  COL12A1    NaN      True       False
# 5     complex:integrin_a2b1_complex  COL13A1    NaN     False       False
# 6     complex:integrin_a2b1_complex  COL14A1    NaN      True       False
# ...                             ...      ...    ...       ...         ...
# 2828                  simple:Q01974    WNT5A   ROR2      True       False
# 2869                  simple:O00533     CHL1   CHL1      True       False
# 2870                complex:CNTF_1R    CLCF1    NaN      True       False
# 2883                  simple:P10721    KITLG    KIT      True       False
# 2903                  simple:Q9BX79     RBP4  STRA6      True       False
#
#       receptor_b annotation_strategy  is_integrin  \
# 0          False             curated         True
# 2          False             curated         True
# 4          False             curated         True
# 5          False             curated         True
# 6          False             curated         True
# ...          ...                 ...          ...
# 2828        True             curated        False
# 2869       False             curated        False
# 2870        True             curated        False
# 2883        True             curated        False
# 2903        True             curated        False
#
#       Müllerian Epi|Müllerian Epi  Müllerian Epi|Wolffian Epi  \
# 0                               0                           1
# 2                               0                           1
# 4                               0                           1
# 5                               0                           0
# 6                               0                           0
# ...                           ...                         ...
# 2828                            0                           0
# 2869                            1                           1
# 2870                            0                           0
# 2883                            0                           0
# 2903                            0                           0
#
#       Müllerian Epi|Müllerian Mese  Müllerian Epi|Wolffian/Mesonephros Mese  \
# 0                                0                                        0
# 2                                0                                        0
# 4                                0                                        0
# 5                                0                                        0
# 6                                0                                        0
# ...                            ...                                      ...
# 2828                             0                                        0
# 2869                             0                                        0
# 2870                             0                                        1
# 2883                             0                                        0
# 2903                             1                                        0
#
#       Wolffian Epi|Müllerian Epi  Wolffian Epi|Wolffian Epi  \
# 0                              1                          1
# 2                              0                          0
# 4                              0                          0
# 5                              0                          0
# 6                              0                          0
# ...                          ...                        ...
# 2828                           0                          0
# 2869                           1                          0
# 2870                           0                          0
# 2883                           1                          0
# 2903                           0                          0
#
#       Wolffian Epi|Müllerian Mese  Wolffian Epi|Wolffian/Mesonephros Mese  \
# 0                               0                                       0
# 2                               0                                       0
# 4                               0                                       0
# 5                               0                                       0
# 6                               0                                       0
# ...                           ...                                     ...
# 2828                            0                                       0
# 2869                            0                                       0
# 2870                            0                                       0
# 2883                            0                                       0
# 2903                            0                                       0
#
#       Müllerian Mese|Müllerian Epi  Müllerian Mese|Wolffian Epi  \
# 0                                0                            0
# 2                                0                            1
# 4                                0                            0
# 5                                0                            1
# 6                                0                            1
# ...                            ...                          ...
# 2828                             0                            0
# 2869                             0                            0
# 2870                             0                            0
# 2883                             0                            0
# 2903                             0                            0
#
#       Müllerian Mese|Müllerian Mese  Müllerian Mese|Wolffian/Mesonephros Mese  \
# 0                                 0                                         0
# 2                                 0                                         0
# 4                                 0                                         0
# 5                                 0                                         0
# 6                                 0                                         0
# ...                             ...                                       ...
# 2828                              0                                         0
# 2869                              0                                         0
# 2870                              0                                         1
# 2883                              0                                         0
# 2903                              0                                         0
#
#       Wolffian/Mesonephros Mese|Müllerian Epi  \
# 0                                           0
# 2                                           0
# 4                                           0
# 5                                           0
# 6                                           1
# ...                                       ...
# 2828                                        1
# 2869                                        0
# 2870                                        0
# 2883                                        0
# 2903                                        0
#
#       Wolffian/Mesonephros Mese|Wolffian Epi  \
# 0                                          0
# 2                                          1
# 4                                          1
# 5                                          1
# 6                                          1
# ...                                      ...
# 2828                                       1
# 2869                                       0
# 2870                                       0
# 2883                                       0
# 2903                                       0
#
#       Wolffian/Mesonephros Mese|Müllerian Mese  \
# 0                                            0
# 2                                            0
# 4                                            0
# 5                                            0
# 6                                            0
# ...                                        ...
# 2828                                         1
# 2869                                         0
# 2870                                         0
# 2883                                         0
# 2903                                         0
#
#       Wolffian/Mesonephros Mese|Wolffian/Mesonephros Mese
# 0                                                     0
# 2                                                     0
# 4                                                     0
# 5                                                     0
# 6                                                     0
# ...                                                 ...
# 2828                                                  1
# 2869                                                  0
# 2870                                                  0
# 2883                                                  0
# 2903                                                  0
#
# [261 rows x 27 columns]

# %%
res['relevant_interactions_result'].head(3)
# Out:
#   id_cp_interaction               interacting_pair      partner_a  \
# 0   CPI-SC0A2DB962D     CDH1_integrin_a2b1_complex  simple:P12830
# 2   CPI-SC0C8B7BCBB  COL11A1_integrin_a2b1_complex  simple:P12107
# 4   CPI-SC0B86B7CED  COL12A1_integrin_a2b1_complex  simple:Q99715
#
#                        partner_b   gene_a gene_b  secreted  receptor_a  \
# 0  complex:integrin_a2b1_complex     CDH1    NaN     False       False
# 2  complex:integrin_a2b1_complex  COL11A1    NaN      True       False
# 4  complex:integrin_a2b1_complex  COL12A1    NaN      True       False
#
#    receptor_b annotation_strategy  is_integrin  Müllerian Epi|Müllerian Epi  \
# 0       False             curated         True                            0
# 2       False             curated         True                            0
# 4       False             curated         True                            0
#
#    Müllerian Epi|Wolffian Epi  Müllerian Epi|Müllerian Mese  \
# 0                           1                             0
# 2                           1                             0
# 4                           1                             0
#
#    Müllerian Epi|Wolffian/Mesonephros Mese  Wolffian Epi|Müllerian Epi  \
# 0                                        0                           1
# 2                                        0                           0
# 4                                        0                           0
#
#    Wolffian Epi|Wolffian Epi  Wolffian Epi|Müllerian Mese  \
# 0                          1                            0
# 2                          0                            0
# 4                          0                            0
#
#    Wolffian Epi|Wolffian/Mesonephros Mese  Müllerian Mese|Müllerian Epi  \
# 0                                       0                             0
# 2                                       0                             0
# 4                                       0                             0
#
#    Müllerian Mese|Wolffian Epi  Müllerian Mese|Müllerian Mese  \
# 0                            0                              0
# 2                            1                              0
# 4                            0                              0
#
#    Müllerian Mese|Wolffian/Mesonephros Mese  \
# 0                                         0
# 2                                         0
# 4                                         0
#
#    Wolffian/Mesonephros Mese|Müllerian Epi  \
# 0                                        0
# 2                                        0
# 4                                        0
#
#    Wolffian/Mesonephros Mese|Wolffian Epi  \
# 0                                       0
# 2                                       1
# 4                                       1
#
#    Wolffian/Mesonephros Mese|Müllerian Mese  \
# 0                                         0
# 2                                         0
# 4                                         0
#
#    Wolffian/Mesonephros Mese|Wolffian/Mesonephros Mese
# 0                                                  0
# 2                                                  0
# 4                                                  0

# %% [markdown]
# **Deconvoluted** fields:
# - **gene_name**: Gene identifier for one of the subunits that are participating in the interaction defined in “means.csv” file. The identifier will depend on the input of the user list.
# - **uniprot**: UniProt identifier for one of the subunits that are participating in the interaction defined in “means.csv” file.
# - **is_complex**: True if the subunit is part of a complex. Single if it is not, complex if it is.
# - **protein_name**: Protein name for one of the subunits that are participating in the interaction defined in “means.csv” file.
# - **complex_name**: Complex name if the subunit is part of a complex. Empty if not.
# - **id_cp_interaction**: Unique CellPhoneDB identifier for each of the interactions stored in the database.
# - **mean**: Mean expression of the corresponding gene in each cluster.

# %%
res['deconvoluted_result'].head(3)
# Out:
#         gene_name uniprot  is_complex protein_name  \
# gene
# UBASH3B   UBASH3B  Q8TF42        True  UBS3B_HUMAN
# UBASH3B   UBASH3B  Q8TF42        True  UBS3B_HUMAN
# UBASH3B   UBASH3B  Q8TF42        True  UBS3B_HUMAN
#
#                          complex_name id_cp_interaction  Müllerian Epi  \
# gene
# UBASH3B  Dehydroepiandrosterone_bySTS   CPI-CS09B8977D7          0.015
# UBASH3B  Dehydroepiandrosterone_bySTS   CPI-CS05760BB78          0.015
# UBASH3B  Dehydroepiandrosterone_bySTS   CPI-CS0259A0EB4          0.015
#
#          Müllerian Mese  Wolffian Epi  Wolffian/Mesonephros Mese
# gene
# UBASH3B           0.153         0.008                      0.055
# UBASH3B           0.153         0.008                      0.055
# UBASH3B           0.153         0.008                      0.055

# %% [markdown]
# **Means** fields:
# - **id_cp_interaction**: Unique CellPhoneDB identifier for each interaction stored in the database.
# - **interacting_pair**: Name of the interacting pairs.
# - **partner A or B**: Identifier for the first interacting partner (A) or the second (B). It could be: UniProt (prefix simple:) or complex (prefix complex:)
# - **gene A or B**: Gene identifier for the first interacting partner (A) or the second (B). The identifier will depend on the input user list.
# - **secreted**: True if one of the partners is secreted.
# - **Receptor A or B**: True if the first interacting partner (A) or the second (B) is annotated as a receptor in our database.
# - **annotation_strategy**: Curated if the interaction was annotated by the CellPhoneDB developers. Otherwise, the name of the database where the interaction has been downloaded from.
# - **is_integrin**: True if one of the partners is integrin.
# - **means**: Mean values for all the interacting partners: mean value refers to the total mean of the individual partner average expression values in the corresponding interacting pairs of cell types. If one of the mean values is 0, then the total mean is set to 0.

# %%
res['means_result'].head(3)
# Out:
#   id_cp_interaction               interacting_pair      partner_a  \
# 0   CPI-SC0A2DB962D     CDH1_integrin_a2b1_complex  simple:P12830
# 2   CPI-SC0C8B7BCBB  COL11A1_integrin_a2b1_complex  simple:P12107
# 3   CPI-SC0D3C12C3F  COL11A2_integrin_a2b1_complex  simple:P13942
#
#                        partner_b   gene_a gene_b  secreted  receptor_a  \
# 0  complex:integrin_a2b1_complex     CDH1    NaN     False       False
# 2  complex:integrin_a2b1_complex  COL11A1    NaN      True       False
# 3  complex:integrin_a2b1_complex  COL11A2    NaN      True       False
#
#    receptor_b annotation_strategy  is_integrin  Müllerian Epi|Müllerian Epi  \
# 0       False             curated         True                        0.183
# 2       False             curated         True                        0.199
# 3       False             curated         True                        0.084
#
#    Müllerian Epi|Wolffian Epi  Müllerian Epi|Müllerian Mese  \
# 0                       0.548                         0.114
# 2                       0.564                         0.130
# 3                       0.449                         0.015
#
#    Müllerian Epi|Wolffian/Mesonephros Mese  Wolffian Epi|Müllerian Epi  \
# 0                                    0.108                       0.783
# 2                                    0.125                       0.108
# 3                                    0.010                       0.106
#
#    Wolffian Epi|Wolffian Epi  Wolffian Epi|Müllerian Mese  \
# 0                      1.148                        0.714
# 2                      0.473                        0.039
# 3                      0.471                        0.037
#
#    Wolffian Epi|Wolffian/Mesonephros Mese  Müllerian Mese|Müllerian Epi  \
# 0                                   0.709                         0.083
# 2                                   0.034                         0.678
# 3                                   0.032                         0.104
#
#    Müllerian Mese|Wolffian Epi  Müllerian Mese|Müllerian Mese  \
# 0                        0.447                          0.014
# 2                        1.043                          0.609
# 3                        0.468                          0.035
#
#    Müllerian Mese|Wolffian/Mesonephros Mese  \
# 0                                     0.008
# 2                                     0.604
# 3                                     0.029
#
#    Wolffian/Mesonephros Mese|Müllerian Epi  \
# 0                                    0.080
# 2                                    0.765
# 3                                    0.086
#
#    Wolffian/Mesonephros Mese|Wolffian Epi  \
# 0                                   0.445
# 2                                   1.130
# 3                                   0.450
#
#    Wolffian/Mesonephros Mese|Müllerian Mese  \
# 0                                     0.011
# 2                                     0.696
# 3                                     0.017
#
#    Wolffian/Mesonephros Mese|Wolffian/Mesonephros Mese
# 0                                              0.005
# 2                                              0.691
# 3                                              0.011

# %% [markdown]
# **Significant means** fields:
# - **id_cp_interaction**: Unique CellPhoneDB identifier for each interaction stored in the database.
# - **interacting_pair**: Name of the interacting pairs.
# - **partner A or B**: Identifier for the first interacting partner (A) or the second (B). It could be: UniProt (prefix simple:) or complex (prefix complex:)
# - **gene A or B**: Gene identifier for the first interacting partner (A) or the second (B). The identifier will depend on the input user list.
# - **secreted**: True if one of the partners is secreted.
# - **Receptor A or B**: True if the first interacting partner (A) or the second (B) is annotated as a receptor in our database.
# - **annotation_strategy**: Curated if the interaction was annotated by the CellPhoneDB developers. Otherwise, the name of the database where the interaction has been downloaded from.
# - **is_integrin**: True if one of the partners is integrin.
# - **significant_mean**: Significant mean calculation for all the interacting partners. If the interaction has been found relevant, the value will be the mean. Alternatively, the value is set to 0.

# %%
res['significant_means'].head(3)
# Out:
#      id_cp_interaction                interacting_pair      partner_a  \
# 168    CPI-SC092A2325E  COL14A1_integrin_a11b1_complex  simple:Q05707
# 37     CPI-SC05640277E    COL7A1_integrin_a2b1_complex  simple:Q02388
# 2818   CPI-SS03C93A8FE                      WNT5A_WIF1  simple:P41221
#
#                            partner_b   gene_a gene_b  secreted  receptor_a  \
# 168   complex:integrin_a11b1_complex  COL14A1    NaN      True       False
# 37     complex:integrin_a2b1_complex   COL7A1    NaN      True       False
# 2818                   simple:Q9Y5W5    WNT5A   WIF1      True       False
#
#       receptor_b annotation_strategy  is_integrin   rank  \
# 168        False             curated         True  0.062
# 37         False             curated         True  0.062
# 2818       False             curated        False  0.062
#
#       Müllerian Epi|Müllerian Epi  Müllerian Epi|Wolffian Epi  \
# 168                           NaN                         NaN
# 37                            NaN                         NaN
# 2818                          NaN                         NaN
#
#       Müllerian Epi|Müllerian Mese  Müllerian Epi|Wolffian/Mesonephros Mese  \
# 168                            NaN                                      NaN
# 37                             NaN                                      NaN
# 2818                           NaN                                      NaN
#
#       Wolffian Epi|Müllerian Epi  Wolffian Epi|Wolffian Epi  \
# 168                          NaN                        NaN
# 37                           NaN                        NaN
# 2818                         NaN                        NaN
#
#       Wolffian Epi|Müllerian Mese  Wolffian Epi|Wolffian/Mesonephros Mese  \
# 168                           NaN                                     NaN
# 37                            NaN                                     NaN
# 2818                          NaN                                     NaN
#
#       Müllerian Mese|Müllerian Epi  Müllerian Mese|Wolffian Epi  \
# 168                            NaN                          NaN
# 37                             NaN                          NaN
# 2818                           NaN                          NaN
#
#       Müllerian Mese|Müllerian Mese  Müllerian Mese|Wolffian/Mesonephros Mese  \
# 168                             NaN                                       NaN
# 37                              NaN                                       NaN
# 2818                            NaN                                       NaN
#
#       Wolffian/Mesonephros Mese|Müllerian Epi  \
# 168                                       NaN
# 37                                        NaN
# 2818                                      NaN
#
#       Wolffian/Mesonephros Mese|Wolffian Epi  \
# 168                                      NaN
# 37                                     0.558
# 2818                                     NaN
#
#       Wolffian/Mesonephros Mese|Müllerian Mese  \
# 168                                        NaN
# 37                                         NaN
# 2818                                     1.593
#
#       Wolffian/Mesonephros Mese|Wolffian/Mesonephros Mese
# 168                                               1.304
# 37                                                  NaN
# 2818                                                NaN

# %%
res['interaction_scores'].head(3)
# Out:
#   id_cp_interaction               interacting_pair      partner_a  \
# 0   CPI-SC0A2DB962D     CDH1_integrin_a2b1_complex  simple:P12830
# 2   CPI-SC0C8B7BCBB  COL11A1_integrin_a2b1_complex  simple:P12107
# 3   CPI-SC0D3C12C3F  COL11A2_integrin_a2b1_complex  simple:P13942
#
#                        partner_b   gene_a gene_b  secreted  receptor_a  \
# 0  complex:integrin_a2b1_complex     CDH1    NaN     False       False
# 2  complex:integrin_a2b1_complex  COL11A1    NaN      True       False
# 3  complex:integrin_a2b1_complex  COL11A2    NaN      True       False
#
#    receptor_b annotation_strategy  is_integrin  Müllerian Epi|Müllerian Epi  \
# 0       False             curated         True                        6.127
# 2       False             curated         True                        7.274
# 3       False             curated         True                        0.000
#
#    Müllerian Epi|Wolffian Epi  Müllerian Epi|Müllerian Mese  \
# 0                      14.873                           0.0
# 2                      17.657                           0.0
# 3                       0.000                           0.0
#
#    Müllerian Epi|Wolffian/Mesonephros Mese  Wolffian Epi|Müllerian Epi  \
# 0                                      0.0                      41.199
# 2                                      0.0                       0.000
# 3                                      0.0                       0.000
#
#    Wolffian Epi|Wolffian Epi  Wolffian Epi|Müllerian Mese  \
# 0                      100.0                          0.0
# 2                        0.0                          0.0
# 3                        0.0                          0.0
#
#    Wolffian Epi|Wolffian/Mesonephros Mese  Müllerian Mese|Müllerian Epi  \
# 0                                     0.0                          0.00
# 2                                     0.0                         35.98
# 3                                     0.0                          0.00
#
#    Müllerian Mese|Wolffian Epi  Müllerian Mese|Müllerian Mese  \
# 0                        0.000                            0.0
# 2                       87.332                            0.0
# 3                        0.000                            0.0
#
#    Müllerian Mese|Wolffian/Mesonephros Mese  \
# 0                                       0.0
# 2                                       0.0
# 3                                       0.0
#
#    Wolffian/Mesonephros Mese|Müllerian Epi  \
# 0                                    0.000
# 2                                   41.199
# 3                                    0.000
#
#    Wolffian/Mesonephros Mese|Wolffian Epi  \
# 0                                     0.0
# 2                                   100.0
# 3                                     0.0
#
#    Wolffian/Mesonephros Mese|Müllerian Mese  \
# 0                                       0.0
# 2                                       0.0
# 3                                       0.0
#
#    Wolffian/Mesonephros Mese|Wolffian/Mesonephros Mese
# 0                                                0.0
# 2                                                0.0
# 3                                                0.0

# %% [markdown]
# # Explore CellPhoneDB results
# This module allows to filter CellPhoneDB results by specifying either
# - **cell types pairs**. We can specify two list of cell types (`query_celltype_1`and `query_celltype_2`), the method will subset the interactions to those pairs of cells. Cell types within each list will not be paired.  If we are interested in filtering interactions ocurring between a given cell to all the rest of cells in the dataset we can define `query_celltype_1 = 'All'` and `query_celltype_2 = ['cellA', 'cellB', ...]`.
# - **genes** The argument `genes` allows the user to filter interactions in which a gene participates.
# - or **specific interactions** to define specific interactions based on the interaction name `query_interactions`.
#
# This method filters the rows and columns of the significant_means file; NaN value correspond to interacting pairs found not significant, non-NaN value correspond to those interacting pairs found relevant.

# %%
from cellphonedb.utils import search_utils

search_results = search_utils.search_analysis_results(
    query_cell_types_1 = ['Wolffian Epi'],  # List of cells 1, will be paired to cells 2 (list or 'All').
    query_cell_types_2 = ['Müllerian Epi', 'Müllerian Mese'],     # List of cells 2, will be paired to cells 1 (list or 'All').
#     query_genes = ['LRP5'],                                       # filter interactions based on the genes participating (list).
#     query_interactions = ['CSF1_CSF1R'],                            # filter intereactions based on their name (list).
    significant_means = res['significant_means'],                          # significant_means file generated by CellPhoneDB.
    deconvoluted = res['deconvoluted_result'],                                    # devonvoluted file generated by CellPhoneDB.
    separator = '|',                                                # separator (default: |) employed to split cells (cellA|cellB).
    long_format = True                                              # converts the output into a wide table, removing non-significant interactions
)

# search_results.head(60)
search_results = search_results[search_results['interacting_cells'].isin(['Wolffian Epi|Müllerian Epi',
                                                                         'Wolffian Epi|Müllerian Mese'])]
print(search_results.shape)

search_results.sort_values('significant_mean', ascending=False).head(50)
# Out:
# (96, 7)
#                                   interacting_pair  \
# 376                                    WNT9B_SFRP1
# 444                                    WNT2B_SFRP1
# 346                                    WNT7B_SFRP1
# 468       atRetinoicAcid_byALDH1A1_RAreceptor_RARB
# 463       atRetinoicAcid_byALDH1A1_RAreceptor_RARA
# 459       atRetinoicAcid_byALDH1A1_RAreceptor_RARG
# 300       atRetinoicAcid_byALDH1A1_RAreceptor_RARA
# 461       atRetinoicAcid_byALDH1A1_RAreceptor_RXRB
# 467  atRetinoicAcid_byALDH1A1_RAreceptor_RARB_RXRB
# 298       atRetinoicAcid_byALDH1A1_RAreceptor_RXRB
# 462       atRetinoicAcid_byALDH1A1_RAreceptor_RXRA
# 464  atRetinoicAcid_byALDH1A1_RAreceptor_RARA_RXRA
# 304  atRetinoicAcid_byALDH1A1_RAreceptor_RARB_RXRB
# 305       atRetinoicAcid_byALDH1A1_RAreceptor_RARB
# 165       atRetinoicAcid_byALDH1A1_RAreceptor_RXRG
# 171  atRetinoicAcid_byALDH1A1_RAreceptor_RARG_RXRG
# 296       atRetinoicAcid_byALDH1A1_RAreceptor_RARG
# 299       atRetinoicAcid_byALDH1A1_RAreceptor_RXRA
# 301  atRetinoicAcid_byALDH1A1_RAreceptor_RARA_RXRA
# 469                                   PDGFA_PDGFRA
# 485                                   PDGFC_PDGFRA
# 480                                    JAG1_NOTCH2
# 435                ProstaglandinE2_byPTGES3_PTGER2
# 312                                    CADM1_CADM1
# 266                                      JAG1_CD46
# 429                                      JAG1_CD46
# 428                                      JAG1_VASN
# 265                                      JAG1_VASN
# 395                                    JAG1_NOTCH3
# 317                                    JAG1_NOTCH2
# 232                                    JAG1_NOTCH3
# 222                                      CHL1_CHL1
# 382                                    DLL3_NOTCH2
# 398                                    JAG1_NOTCH1
# 235                                    JAG1_NOTCH1
# 377                                    EFNA1_EPHA7
# 451                                    SDC2_ADGRA2
# 213                                    WNT9B_SFRP1
# 352                                     NTN4_UNC5B
# 447                                WNT9B_FZD2_LRP6
# 335                                     WNT9B_WIF1
# 284                                WNT9B_FZD2_LRP6
# 170                               WNT9B_FZD10_LRP6
# 193                                WNT9B_FZD6_LRP6
# 283                                WNT9B_FZD3_LRP6
# 421                                WNT9B_FZD1_LRP6
# 207                                    EFNA1_EPHA2
# 431                                WNT9B_FZD4_LRP6
# 230                                WNT9B_FZD7_LRP6
# 260                                WNT9B_FZD3_LRP5
#
#                             partner_a                     partner_b gene_a  \
# 376                     simple:O14905                 simple:Q8N474  WNT9B
# 444                     simple:Q93097                 simple:Q8N474  WNT2B
# 346                     simple:P56706                 simple:Q8N474  WNT7B
# 468  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RARB    NaN
# 463  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RARA    NaN
# 459  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RARG    NaN
# 300  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RARA    NaN
# 461  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RXRB    NaN
# 467  complex:atRetinoicAcid_byALDH1A1  complex:RAreceptor_RARB_RXRB    NaN
# 298  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RXRB    NaN
# 462  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RXRA    NaN
# 464  complex:atRetinoicAcid_byALDH1A1  complex:RAreceptor_RARA_RXRA    NaN
# 304  complex:atRetinoicAcid_byALDH1A1  complex:RAreceptor_RARB_RXRB    NaN
# 305  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RARB    NaN
# 165  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RXRG    NaN
# 171  complex:atRetinoicAcid_byALDH1A1  complex:RAreceptor_RARG_RXRG    NaN
# 296  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RARG    NaN
# 299  complex:atRetinoicAcid_byALDH1A1       complex:RAreceptor_RXRA    NaN
# 301  complex:atRetinoicAcid_byALDH1A1  complex:RAreceptor_RARA_RXRA    NaN
# 469                     simple:P04085                 simple:P16234  PDGFA
# 485                     simple:Q9NRA1                 simple:P16234  PDGFC
# 480                     simple:P78504                 simple:Q04721   JAG1
# 435  complex:ProstaglandinE2_byPTGES3                 simple:P43116    NaN
# 312                     simple:Q9BY67                 simple:Q9BY67  CADM1
# 266                     simple:P78504                 simple:P15529   JAG1
# 429                     simple:P78504                 simple:P15529   JAG1
# 428                     simple:P78504                 simple:Q6EMK4   JAG1
# 265                     simple:P78504                 simple:Q6EMK4   JAG1
# 395                     simple:P78504                 simple:Q9UM47   JAG1
# 317                     simple:P78504                 simple:Q04721   JAG1
# 232                     simple:P78504                 simple:Q9UM47   JAG1
# 222                     simple:O00533                 simple:O00533   CHL1
# 382                     simple:Q9NYJ7                 simple:Q04721   DLL3
# 398                     simple:P78504                 simple:P46531   JAG1
# 235                     simple:P78504                 simple:P46531   JAG1
# 377                     simple:P20827                 simple:Q15375  EFNA1
# 451                     simple:P34741                 simple:Q96PE1   SDC2
# 213                     simple:O14905                 simple:Q8N474  WNT9B
# 352                     simple:Q9HB63                 simple:Q8IZJ1   NTN4
# 447                     simple:O14905             complex:FZD2_LRP6  WNT9B
# 335                     simple:O14905                 simple:Q9Y5W5  WNT9B
# 284                     simple:O14905             complex:FZD2_LRP6  WNT9B
# 170                     simple:O14905            complex:FZD10_LRP6  WNT9B
# 193                     simple:O14905             complex:FZD6_LRP6  WNT9B
# 283                     simple:O14905             complex:FZD3_LRP6  WNT9B
# 421                     simple:O14905             complex:FZD1_LRP6  WNT9B
# 207                     simple:P20827                 simple:P29317  EFNA1
# 431                     simple:O14905             complex:FZD4_LRP6  WNT9B
# 230                     simple:O14905             complex:FZD7_LRP6  WNT9B
# 260                     simple:O14905             complex:FZD3_LRP5  WNT9B
#
#      gene_b            interacting_cells  significant_mean
# 376   SFRP1  Wolffian Epi|Müllerian Mese            14.244
# 444   SFRP1  Wolffian Epi|Müllerian Mese            13.437
# 346   SFRP1  Wolffian Epi|Müllerian Mese            13.403
# 468     NaN  Wolffian Epi|Müllerian Mese             3.988
# 463     NaN  Wolffian Epi|Müllerian Mese             3.862
# 459     NaN  Wolffian Epi|Müllerian Mese             3.718
# 300     NaN   Wolffian Epi|Müllerian Epi             3.700
# 461     NaN  Wolffian Epi|Müllerian Mese             3.674
# 467     NaN  Wolffian Epi|Müllerian Mese             3.674
# 298     NaN   Wolffian Epi|Müllerian Epi             3.621
# 462     NaN  Wolffian Epi|Müllerian Mese             3.598
# 464     NaN  Wolffian Epi|Müllerian Mese             3.598
# 304     NaN   Wolffian Epi|Müllerian Epi             3.556
# 305     NaN   Wolffian Epi|Müllerian Epi             3.556
# 165     NaN   Wolffian Epi|Müllerian Epi             3.533
# 171     NaN   Wolffian Epi|Müllerian Epi             3.519
# 296     NaN   Wolffian Epi|Müllerian Epi             3.519
# 299     NaN   Wolffian Epi|Müllerian Epi             3.515
# 301     NaN   Wolffian Epi|Müllerian Epi             3.515
# 469  PDGFRA  Wolffian Epi|Müllerian Mese             3.306
# 485  PDGFRA  Wolffian Epi|Müllerian Mese             3.148
# 480  NOTCH2  Wolffian Epi|Müllerian Mese             2.994
# 435  PTGER2  Wolffian Epi|Müllerian Mese             2.920
# 312   CADM1   Wolffian Epi|Müllerian Epi             2.516
# 266    CD46   Wolffian Epi|Müllerian Epi             2.067
# 429    CD46  Wolffian Epi|Müllerian Mese             1.975
# 428    VASN  Wolffian Epi|Müllerian Mese             1.908
# 265    VASN   Wolffian Epi|Müllerian Epi             1.831
# 395  NOTCH3  Wolffian Epi|Müllerian Mese             1.770
# 317  NOTCH2   Wolffian Epi|Müllerian Epi             1.750
# 232  NOTCH3   Wolffian Epi|Müllerian Epi             1.730
# 222    CHL1   Wolffian Epi|Müllerian Epi             1.689
# 382  NOTCH2  Wolffian Epi|Müllerian Mese             1.662
# 398  NOTCH1  Wolffian Epi|Müllerian Mese             1.521
# 235  NOTCH1   Wolffian Epi|Müllerian Epi             1.496
# 377   EPHA7  Wolffian Epi|Müllerian Mese             1.475
# 451  ADGRA2  Wolffian Epi|Müllerian Mese             1.391
# 213   SFRP1   Wolffian Epi|Müllerian Epi             1.317
# 352   UNC5B  Wolffian Epi|Müllerian Mese             1.299
# 447     NaN  Wolffian Epi|Müllerian Mese             1.262
# 335    WIF1  Wolffian Epi|Müllerian Mese             1.251
# 284     NaN   Wolffian Epi|Müllerian Epi             1.237
# 170     NaN   Wolffian Epi|Müllerian Epi             1.237
# 193     NaN   Wolffian Epi|Müllerian Epi             1.237
# 283     NaN   Wolffian Epi|Müllerian Epi             1.237
# 421     NaN  Wolffian Epi|Müllerian Mese             1.211
# 207   EPHA2   Wolffian Epi|Müllerian Epi             1.148
# 431     NaN  Wolffian Epi|Müllerian Mese             1.137
# 230     NaN   Wolffian Epi|Müllerian Epi             1.132
# 260     NaN   Wolffian Epi|Müllerian Epi             1.126

# %%
from cellphonedb.utils import search_utils

search_results = search_utils.search_analysis_results(
    query_cell_types_1 = ['Wolffian/Mesonephros Mese'],  # List of cells 1, will be paired to cells 2 (list or 'All').
    query_cell_types_2 = ['Müllerian Epi', 'Müllerian Mese'],     # List of cells 2, will be paired to cells 1 (list or 'All').
#     query_genes = ['LRP5'],                                       # filter interactions based on the genes participating (list).
#     query_interactions = ['CSF1_CSF1R'],                            # filter intereactions based on their name (list).
    significant_means = res['significant_means'],                          # significant_means file generated by CellPhoneDB.
    deconvoluted = res['deconvoluted_result'],                                    # devonvoluted file generated by CellPhoneDB.
    separator = '|',                                                # separator (default: |) employed to split cells (cellA|cellB).
    long_format = True                                              # converts the output into a wide table, removing non-significant interactions
)

# search_results.head(60)
search_results = search_results[search_results['interacting_cells'].isin(['Wolffian/Mesonephros Mese|Müllerian Epi',
                                                                         'Wolffian/Mesonephros Mese|Müllerian Mese'])]
print(search_results.shape)
search_results.sort_values('significant_mean', ascending=False).tail(50)
# Out:
# (112, 7)
#                     interacting_pair                         partner_a  \
# 411                       WNT5A_WIF1                     simple:P41221
# 482                       WNT5A_ROR2                     simple:P41221
# 285                  WNT5A_FZD6_LRP6                     simple:P41221
# 365                  WNT5A_FZD2_LRP6                     simple:P41221
# 315                 WNT5A_FZD10_LRP6                     simple:P41221
# 361                  WNT5A_FZD3_LRP6                     simple:P41221
# 442                     CXCL12_CXCR4                     simple:P48061
# 314                  WNT4_FZD10_LRP5                     simple:P56705
# 519                  WNT5A_FZD4_LRP6                     simple:P41221
# 349                  WNT5A_FZD7_LRP6                     simple:P41221
# 352                  WNT5A_FZD7_LRP5                     simple:P41221
# 284                  WNT5A_FZD6_LRP5                     simple:P41221
# 318                 WNT5A_FZD10_LRP5                     simple:P41221
# 377                  WNT5A_FZD3_LRP5                     simple:P41221
# 331                  WNT5A_FZD2_LRP5                     simple:P41221
# 498                  WNT5A_FZD3_LRP6                     simple:P41221
# 299                      CXCL12_DPP4                     simple:P48061
# 468                  WNT5A_FZD2_LRP5                     simple:P41221
# 512                  WNT5A_FZD4_LRP5                     simple:P41221
# 514                  WNT5A_FZD3_LRP5                     simple:P41221
# 430                       WNT5A_FRZB                     simple:P41221
# 385                       WNT5A_ROR1                     simple:P41221
# 489                  WNT5A_FZD7_LRP5                     simple:P41221
# 486                  WNT5A_FZD7_LRP6                     simple:P41221
# 382                  WNT5A_FZD4_LRP6                     simple:P41221
# 375                  WNT5A_FZD4_LRP5                     simple:P41221
# 345                       WNT5A_ROR2                     simple:P41221
# 494    COL14A1_integrin_a1b1_complex                     simple:Q05707
# 447        TNC_integrin_a8b1_complex                     simple:P24821
# 487    COL21A1_integrin_a1b1_complex                     simple:Q96P44
# 435                      SDC1_ADGRA2                     simple:P18827
# 320    COL14A1_integrin_a2b1_complex                     simple:Q05707
# 357    COL14A1_integrin_a1b1_complex                     simple:Q05707
# 319    COL21A1_integrin_a2b1_complex                     simple:Q96P44
# 350    COL21A1_integrin_a1b1_complex                     simple:Q96P44
# 313                TNFSF12_TNFRSF12A                     simple:O43508
# 291        TNC_integrin_a4b1_complex                     simple:P24821
# 461       FBN1_integrin_a5b1_complex                     simple:P35555
# 460    COL15A1_integrin_a1b1_complex                     simple:P39059
# 324       FBN1_integrin_a5b1_complex                     simple:P35555
# 425        TNC_integrin_a9b1_complex                     simple:P24821
# 310        TNC_integrin_a8b1_complex                     simple:P24821
# 499  ProstaglandinE2_byPTGES2_PTGER2  complex:ProstaglandinE2_byPTGES2
# 297    COL15A1_integrin_a2b1_complex                     simple:P39059
# 323    COL15A1_integrin_a1b1_complex                     simple:P39059
# 504   ProstaglandinE2_byPTGES_PTGER2   complex:ProstaglandinE2_byPTGES
# 317                 WNT11_FZD10_LRP6                     simple:O96014
# 309                 WNT11_FZD10_LRP5                     simple:O96014
# 333                 WNT2B_FZD10_LRP6                     simple:Q93097
# 347                 WNT2B_FZD10_LRP5                     simple:Q93097
#
#                          partner_b   gene_a     gene_b  \
# 411                  simple:Q9Y5W5    WNT5A       WIF1
# 482                  simple:Q01974    WNT5A       ROR2
# 285              complex:FZD6_LRP6    WNT5A        NaN
# 365              complex:FZD2_LRP6    WNT5A        NaN
# 315             complex:FZD10_LRP6    WNT5A        NaN
# 361              complex:FZD3_LRP6    WNT5A        NaN
# 442                  simple:P61073   CXCL12      CXCR4
# 314             complex:FZD10_LRP5     WNT4        NaN
# 519              complex:FZD4_LRP6    WNT5A        NaN
# 349              complex:FZD7_LRP6    WNT5A        NaN
# 352              complex:FZD7_LRP5    WNT5A        NaN
# 284              complex:FZD6_LRP5    WNT5A        NaN
# 318             complex:FZD10_LRP5    WNT5A        NaN
# 377              complex:FZD3_LRP5    WNT5A        NaN
# 331              complex:FZD2_LRP5    WNT5A        NaN
# 498              complex:FZD3_LRP6    WNT5A        NaN
# 299                  simple:P27487   CXCL12       DPP4
# 468              complex:FZD2_LRP5    WNT5A        NaN
# 512              complex:FZD4_LRP5    WNT5A        NaN
# 514              complex:FZD3_LRP5    WNT5A        NaN
# 430                  simple:Q92765    WNT5A       FRZB
# 385                  simple:Q01973    WNT5A       ROR1
# 489              complex:FZD7_LRP5    WNT5A        NaN
# 486              complex:FZD7_LRP6    WNT5A        NaN
# 382              complex:FZD4_LRP6    WNT5A        NaN
# 375              complex:FZD4_LRP5    WNT5A        NaN
# 345                  simple:Q01974    WNT5A       ROR2
# 494  complex:integrin_a1b1_complex  COL14A1        NaN
# 447  complex:integrin_a8b1_complex      TNC        NaN
# 487  complex:integrin_a1b1_complex  COL21A1        NaN
# 435                  simple:Q96PE1     SDC1     ADGRA2
# 320  complex:integrin_a2b1_complex  COL14A1        NaN
# 357  complex:integrin_a1b1_complex  COL14A1        NaN
# 319  complex:integrin_a2b1_complex  COL21A1        NaN
# 350  complex:integrin_a1b1_complex  COL21A1        NaN
# 313                  simple:Q9NP84  TNFSF12  TNFRSF12A
# 291  complex:integrin_a4b1_complex      TNC        NaN
# 461  complex:integrin_a5b1_complex     FBN1        NaN
# 460  complex:integrin_a1b1_complex  COL15A1        NaN
# 324  complex:integrin_a5b1_complex     FBN1        NaN
# 425  complex:integrin_a9b1_complex      TNC        NaN
# 310  complex:integrin_a8b1_complex      TNC        NaN
# 499                  simple:P43116      NaN     PTGER2
# 297  complex:integrin_a2b1_complex  COL15A1        NaN
# 323  complex:integrin_a1b1_complex  COL15A1        NaN
# 504                  simple:P43116      NaN     PTGER2
# 317             complex:FZD10_LRP6    WNT11        NaN
# 309             complex:FZD10_LRP5    WNT11        NaN
# 333             complex:FZD10_LRP6    WNT2B        NaN
# 347             complex:FZD10_LRP5    WNT2B        NaN
#
#                             interacting_cells  significant_mean
# 411  Wolffian/Mesonephros Mese|Müllerian Mese             1.593
# 482  Wolffian/Mesonephros Mese|Müllerian Mese             1.586
# 285   Wolffian/Mesonephros Mese|Müllerian Epi             1.578
# 365   Wolffian/Mesonephros Mese|Müllerian Epi             1.578
# 315   Wolffian/Mesonephros Mese|Müllerian Epi             1.578
# 361   Wolffian/Mesonephros Mese|Müllerian Epi             1.578
# 442  Wolffian/Mesonephros Mese|Müllerian Mese             1.574
# 314   Wolffian/Mesonephros Mese|Müllerian Epi             1.515
# 519  Wolffian/Mesonephros Mese|Müllerian Mese             1.479
# 349   Wolffian/Mesonephros Mese|Müllerian Epi             1.474
# 352   Wolffian/Mesonephros Mese|Müllerian Epi             1.468
# 284   Wolffian/Mesonephros Mese|Müllerian Epi             1.468
# 318   Wolffian/Mesonephros Mese|Müllerian Epi             1.468
# 377   Wolffian/Mesonephros Mese|Müllerian Epi             1.468
# 331   Wolffian/Mesonephros Mese|Müllerian Epi             1.468
# 498  Wolffian/Mesonephros Mese|Müllerian Mese             1.455
# 299   Wolffian/Mesonephros Mese|Müllerian Epi             1.449
# 468  Wolffian/Mesonephros Mese|Müllerian Mese             1.430
# 512  Wolffian/Mesonephros Mese|Müllerian Mese             1.430
# 514  Wolffian/Mesonephros Mese|Müllerian Mese             1.430
# 430  Wolffian/Mesonephros Mese|Müllerian Mese             1.405
# 385   Wolffian/Mesonephros Mese|Müllerian Epi             1.405
# 489  Wolffian/Mesonephros Mese|Müllerian Mese             1.378
# 486  Wolffian/Mesonephros Mese|Müllerian Mese             1.378
# 382   Wolffian/Mesonephros Mese|Müllerian Epi             1.357
# 375   Wolffian/Mesonephros Mese|Müllerian Epi             1.357
# 345   Wolffian/Mesonephros Mese|Müllerian Epi             1.353
# 494  Wolffian/Mesonephros Mese|Müllerian Mese             1.350
# 447  Wolffian/Mesonephros Mese|Müllerian Mese             1.322
# 487  Wolffian/Mesonephros Mese|Müllerian Mese             1.279
# 435  Wolffian/Mesonephros Mese|Müllerian Mese             1.247
# 320   Wolffian/Mesonephros Mese|Müllerian Epi             1.247
# 357   Wolffian/Mesonephros Mese|Müllerian Epi             1.234
# 319   Wolffian/Mesonephros Mese|Müllerian Epi             1.176
# 350   Wolffian/Mesonephros Mese|Müllerian Epi             1.163
# 313   Wolffian/Mesonephros Mese|Müllerian Epi             1.073
# 291   Wolffian/Mesonephros Mese|Müllerian Epi             0.944
# 461  Wolffian/Mesonephros Mese|Müllerian Mese             0.929
# 460  Wolffian/Mesonephros Mese|Müllerian Mese             0.922
# 324   Wolffian/Mesonephros Mese|Müllerian Epi             0.898
# 425  Wolffian/Mesonephros Mese|Müllerian Mese             0.873
# 310   Wolffian/Mesonephros Mese|Müllerian Epi             0.873
# 499  Wolffian/Mesonephros Mese|Müllerian Mese             0.852
# 297   Wolffian/Mesonephros Mese|Müllerian Epi             0.818
# 323   Wolffian/Mesonephros Mese|Müllerian Epi             0.805
# 504  Wolffian/Mesonephros Mese|Müllerian Mese             0.662
# 317   Wolffian/Mesonephros Mese|Müllerian Epi             0.612
# 309   Wolffian/Mesonephros Mese|Müllerian Epi             0.501
# 333   Wolffian/Mesonephros Mese|Müllerian Epi             0.424
# 347   Wolffian/Mesonephros Mese|Müllerian Epi             0.313

# %% [markdown]
# ### Save interactions for supplementary table

# %%
from cellphonedb.utils import search_utils

search_results = search_utils.search_analysis_results(
    query_cell_types_1 = ['Wolffian Epi', 'Wolffian/Mesonephros Mese'],  # List of cells 1, will be paired to cells 2 (list or 'All').
    query_cell_types_2 = ['Müllerian Mese', 'Müllerian Epi'],     # List of cells 2, will be paired to cells 1 (list or 'All').
#     query_genes = ['LRP5'],                                       # filter interactions based on the genes participating (list).
#     query_interactions = ['CSF1_CSF1R'],                            # filter intereactions based on their name (list).
    significant_means = res['significant_means'],                          # significant_means file generated by CellPhoneDB.
    deconvoluted = res['deconvoluted_result'],                                    # devonvoluted file generated by CellPhoneDB.
    separator = '|',                                                # separator (default: |) employed to split cells (cellA|cellB).
    long_format = True                                              # converts the output into a wide table, removing non-significant interactions
)

# search_results.head(60)
search_results = search_results[search_results['interacting_cells'].isin(['Wolffian/Mesonephros Mese|Müllerian Mese',
                                                                         'Wolffian/Mesonephros Mese|Müllerian Epi', 
                                                                         'Wolffian Epi|Müllerian Mese', 
                                                                         'Wolffian Epi|Müllerian Epi'])]
print(search_results.shape)
# search_results.sort_values('significant_mean', ascending=False).tail(50)
# Out:
# (208, 7)

# %%
search_results.to_csv('/nfs/team292/vl6/FetalReproductiveTract/CellPhoneDB/Mullerian_and_Wolffian_early/output/wolffian_to_mullerian_signalling.csv')

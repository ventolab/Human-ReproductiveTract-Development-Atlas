# %% [markdown]
# ## Create Milo object for cross-species comparison

# %%
suppressPackageStartupMessages(
{library(SingleCellExperiment)
library(biomaRt)
library(data.table)
library(scater)
library(BiocParallel)
library(scran)
library(miloR)
}
)

# %%
# if (!require("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")

# BiocManager::install("miloR")

# %% [markdown]
# ### 1. Load RDS object

# %%
mouse_dir <- "/nfs/team292/vl6/FetalReproductiveTract/"

# %%
sce <- readRDS(paste0(mouse_dir, "mouse_genital_tubercle_mpw_orthologs.rds"))
sce
# Out:
# class: SingleCellExperiment
# dim: 2530 60832
# metadata(0):
# assays(3): X raw_counts log_normalised_counts
# rownames(2530): Adamts5 Adra1d ... Tnni1 Tnnt2
# rowData names(43): gene_ids.0 feature_types.0 ...
#   highly_variable_nbatches highly_variable_intersection
# colnames(60832): GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG
#   GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT ...
#   GSM5324574_E18.5_female_genitalia_2_TTTGTTGTCATAGGCT
#   GSM5324574_E18.5_female_genitalia_2_TTTGTTGTCATTTCCA
# colData names(7): sample donor ... species celltype
# reducedDimNames(3): PCA UMAP X_pca_harmony
# mainExpName: NULL
# altExpNames(0):

# %% [markdown]
# ### 2. Format the SCE object with appropriate slots for raw and normalised counts

# %%
assay(sce, "counts") <- assay(sce, "raw_counts")
assay(sce, "logcounts") <- assay(sce, "log_normalised_counts")

# %%
sce
# Out:
# class: SingleCellExperiment
# dim: 2530 60832
# metadata(0):
# assays(5): X raw_counts log_normalised_counts counts logcounts
# rownames(2530): Adamts5 Adra1d ... Tnni1 Tnnt2
# rowData names(43): gene_ids.0 feature_types.0 ...
#   highly_variable_nbatches highly_variable_intersection
# colnames(60832): GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG
#   GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT ...
#   GSM5324574_E18.5_female_genitalia_2_TTTGTTGTCATAGGCT
#   GSM5324574_E18.5_female_genitalia_2_TTTGTTGTCATTTCCA
# colData names(7): sample donor ... species celltype
# reducedDimNames(3): PCA UMAP X_pca_harmony
# mainExpName: NULL
# altExpNames(0):

# %%
# Remove unnecessary assay slots 
assay(sce, "X") <- NULL
assay(sce, "raw_counts") <- NULL
assay(sce, "log_normalised_counts") <- NULL

# %% [markdown]
# ### 5. Create Milo object on Harmony-corrected embedding

# %%
sce_milo <- Milo(sce)

# %%
sce_milo
# Out:
# class: Milo
# dim: 2530 60832
# metadata(0):
# assays(2): counts logcounts
# rownames(2530): Adamts5 Adra1d ... Tnni1 Tnnt2
# rowData names(43): gene_ids.0 feature_types.0 ...
#   highly_variable_nbatches highly_variable_intersection
# colnames(60832): GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG
#   GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT ...
#   GSM5324574_E18.5_female_genitalia_2_TTTGTTGTCATAGGCT
#   GSM5324574_E18.5_female_genitalia_2_TTTGTTGTCATTTCCA
# colData names(7): sample donor ... species celltype
# reducedDimNames(3): PCA UMAP X_pca_harmony
# mainExpName: NULL
# altExpNames(0):
# nhoods dimensions(2): 1 1
# nhoodCounts dimensions(2): 1 1
# nhoodDistances dimension(1): 0
# graph names(0):
# nhoodIndex names(1): 0
# nhoodExpression dimension(2): 1 1
# nhoodReducedDim names(0):
# nhoodGraph names(0):
# nhoodAdjacency dimension(2): 1 1

# %%
k_neigh <- 15
n_comp <- 25
prop_indexCell <- 0.05

# %%
sce_milo <- buildGraph(sce_milo, k=k_neigh, d=n_comp, reduced.dim="X_pca_harmony", BPPARAM=MulticoreParam(7))
# Out:
# Constructing kNN graph with k:15

# %%
sce_milo <- makeNhoods(sce_milo, prop=prop_indexCell, k=k_neigh, d=n_comp, refined=TRUE, reduced_dims="X_pca_harmony")
# Out:
# Checking valid object

# %%
plotNhoodSizeHist(sce_milo)
# Out:
# plot without title

# %%
sce_milo <- buildNhoodGraph(sce_milo)

# %%
p3 <- plotNhoodGraph(sce_milo, size_range=c(1,4), node_stroke=0.1, layout="UMAP") + 
    viridis::scale_fill_viridis(name = "Nhood size", option = "viridis", direction = 1) 
plot(p3)
# Out:
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# plot without title

# %% [markdown]
# ### 6. Save Milo object

# %%
saveRDS(sce_milo, paste0(mouse_dir, "mouse_genital_tubercle_mpw_milo_15knn.rds"))

# %%
mouse_dir
# Out:
# [1] "/nfs/team292/vl6/FetalReproductiveTract/"

# %%
prova <- as.data.frame(as.matrix(nhoods(sce_milo)))
# Out:
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.3 GiB”

# %%
rownames(prova) <- colnames(sce_milo)

# %%
head(prova)
# Out:
#                                                    2988 6030 20298 2755 36522
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG 0    0    0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT 0    0    0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTTTCAGC 0    0    0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCACAATGGCAG 0    0    0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAGTTTCCAAG 0    0    0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCATCCGATGTA 0    0    0     0    0
#                                                    28680 45566 7365 14632 40012
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG 0     0     0    0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT 0     0     0    0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTTTCAGC 0     0     0    0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCACAATGGCAG 0     0     0    0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAGTTTCCAAG 0     0     0    0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCATCCGATGTA 0     0     0    0     0
#                                                    ⋯ 26500 23300 56696 897
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG ⋯ 0     0     0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT ⋯ 0     0     0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTTTCAGC ⋯ 0     0     0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCACAATGGCAG ⋯ 0     0     0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAGTTTCCAAG ⋯ 0     0     0     0
# GSM5324563_E14.5_male_genitalia_1_AAACCCATCCGATGTA ⋯ 0     0     0     0
#                                                    34329 22229 47604 8572 4804
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG 0     0     0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT 0     0     0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTTTCAGC 0     0     0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCACAATGGCAG 0     0     0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAGTTTCCAAG 0     0     0     0    0
# GSM5324563_E14.5_male_genitalia_1_AAACCCATCCGATGTA 0     0     0     0    1
#                                                    53595
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGAAGGTAG 0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTCCCAAT 0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAAGTTTCAGC 0
# GSM5324563_E14.5_male_genitalia_1_AAACCCACAATGGCAG 0
# GSM5324563_E14.5_male_genitalia_1_AAACCCAGTTTCCAAG 0
# GSM5324563_E14.5_male_genitalia_1_AAACCCATCCGATGTA 0

# %%
write.csv(prova, paste0(mouse_dir, "mouse_genital_tubercle_mpw_milo_15knn.csv"))

# %%
dim(prova)
# Out:
# [1] 60832  2766
